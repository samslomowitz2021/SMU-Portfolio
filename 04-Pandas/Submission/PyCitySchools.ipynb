# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
schools_count = school_data_complete.school_name.nunique()
schools_count
# Out:
# 15

# %%
students_count = school_data_complete["Student ID"].nunique()
students_count
# Out:
# 39170

# %%
#https://stackoverflow.com/questions/32072076/find-the-unique-values-in-a-column-and-then-sort-them
a = school_data_complete['budget'].drop_duplicates()
b = a.sum()

# %%
math = school_data_complete.math_score.mean()
math
# Out:
# 78.98537145774827

# %%
reading = school_data_complete.reading_score.mean()
reading
# Out:
# 81.87784018381414

# %%
passed_math = school_data_complete.loc[school_data_complete["math_score"]>69.9999999,:] 
passed_math2 = passed_math["math_score"].count() 
passed_math3 = passed_math2 / students_count * 100
passed_math3
# Out:
# 74.9808526933878

# %%
passed_reading = school_data_complete.loc[school_data_complete["reading_score"]>69.9999999,:] 
passed_reading2 = passed_reading["reading_score"].count() 
passed_reading3 = passed_reading2 / students_count * 100

# %%
# passed_both = school_data_complete.loc[(school_data_complete["math_score"]>69.9999999) | (school_data_complete["reading_score"]>69.9999999),:]
# passed_both["reading_score"].count()

school_data_complete2 = school_data_complete[['math_score','reading_score']][(school_data_complete["math_score"] >69.9999999) & (school_data_complete["reading_score"] >69.9999999)]

school_data_complete3 = school_data_complete2.count()

school_data_complete4 = school_data_complete3 / students_count 
school_data_complete5 = school_data_complete4["math_score"] *100

# %%
series_1 = pd.Series([schools_count])
series_2 = pd.Series([students_count])
series_3 = pd.Series([b])
series_4 = pd.Series([math])
series_5 = pd.Series([reading])
series_6 = pd.Series([passed_math3])
series_7 = pd.Series([passed_reading3])
series_8 = pd.Series([school_data_complete5])

df = pd.DataFrame(columns = ['Total Schools'])
df = pd.DataFrame(columns = ['Total Students'])
df = pd.DataFrame(columns = ['Total Budget'])
df = pd.DataFrame(columns = ['Average Math Score'])
df = pd.DataFrame(columns = ['Average Reading Score'])
df = pd.DataFrame(columns = ['% Passing Math'])
df = pd.DataFrame(columns = ['% Passing Reading'])
df = pd.DataFrame(columns = ['% Overall Passing'])


df['Total Schools'] = series_1
df['Total Students'] = series_2
df['Total Budget'] = series_3
df['Average Math Score'] = series_4
df['Average Reading Score'] = series_5
df['% Passing Math'] = series_6
df['% Passing Reading'] = series_7
df['% Overall Passing'] = series_8

df2 = df[['Total Schools', 'Total Students', 'Total Budget',
       'Average Math Score', 'Average Reading Score', '% Passing Math',
       '% Passing Reading', '% Overall Passing']]
df2
df2.style.format({'Total Schools':"{:20,.0f}", 'Total Students':"{:20,.0f}", 'Total Budget':"{:20,.0f}",
       'Average Math Score':"{:20,.2f}", 'Average Reading Score':"{:20,.2f}", '% Passing Math':"{:20,.2f}",
       '% Passing Reading':"{:20,.2f}", '% Overall Passing': "{:20,.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_52205_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Schools</th>
#       <th class="col_heading level0 col1" >Total Students</th>
#       <th class="col_heading level0 col2" >Total Budget</th>
#       <th class="col_heading level0 col3" >Average Math Score</th>
#       <th class="col_heading level0 col4" >Average Reading Score</th>
#       <th class="col_heading level0 col5" >% Passing Math</th>
#       <th class="col_heading level0 col6" >% Passing Reading</th>
#       <th class="col_heading level0 col7" >% Overall Passing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52205_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_52205_row0_col0" class="data row0 col0" >                  15</td>
#       <td id="T_52205_row0_col1" class="data row0 col1" >              39,170</td>
# ...

# %%
#https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.DataFrameGroupBy.aggregate.html

school_type = school_data_complete.groupby(["school_name"]).agg({"type": "max", "Student ID": "count", "budget": "max" })
school_type
# Out:
#                            type  Student ID   budget
# school_name
# Bailey High School     District        4976  3124928
# Cabrera High School     Charter        1858  1081356
# Figueroa High School   District        2949  1884411
# Ford High School       District        2739  1763916
# Griffin High School     Charter        1468   917500
# Hernandez High School  District        4635  3022020
# Holden High School      Charter         427   248087
# Huang High School      District        2917  1910635
# Johnson High School    District        4761  3094650
# Pena High School        Charter         962   585858
# Rodriguez High School  District        3999  2547363
# Shelton High School     Charter        1761  1056600
# Thomas High School      Charter        1635  1043130
# Wilson High School      Charter        2283  1319574
# Wright High School      Charter        1800  1049400

# %%
school_type["per Student Budget"] = school_type.budget / school_type["Student ID"]
school_type300 = school_type
school_type300
# Out:
#                            type  Student ID   budget  per Student Budget
# school_name
# Bailey High School     District        4976  3124928               628.0
# Cabrera High School     Charter        1858  1081356               582.0
# Figueroa High School   District        2949  1884411               639.0
# Ford High School       District        2739  1763916               644.0
# Griffin High School     Charter        1468   917500               625.0
# Hernandez High School  District        4635  3022020               652.0
# Holden High School      Charter         427   248087               581.0
# Huang High School      District        2917  1910635               655.0
# Johnson High School    District        4761  3094650               650.0
# Pena High School        Charter         962   585858               609.0
# Rodriguez High School  District        3999  2547363               637.0
# Shelton High School     Charter        1761  1056600               600.0
# ...

# %%
#https://www.kite.com/python/answers/how-to-drop-the-index-column-of-a-pandas-dataframe-in-python#:~:text=reset_index()%20to%20drop%20the,reset%20the%20index%20of%20pandas.

school_type2 = school_data_complete.groupby(["school_name"]).agg({"math_score":"mean"})
school_type2
# Out:
#                        math_score
# school_name
# Bailey High School      77.048432
# Cabrera High School     83.061895
# Figueroa High School    76.711767
# Ford High School        77.102592
# Griffin High School     83.351499
# Hernandez High School   77.289752
# Holden High School      83.803279
# Huang High School       76.629414
# Johnson High School     77.072464
# Pena High School        83.839917
# Rodriguez High School   76.842711
# Shelton High School     83.359455
# Thomas High School      83.418349
# Wilson High School      83.274201
# Wright High School      83.682222

# %%
school_type3 = school_data_complete.groupby(["school_name"]).agg({"reading_score":"mean"})
school_type3
school_type3
# Out:
#                        reading_score
# school_name
# Bailey High School         81.033963
# Cabrera High School        83.975780
# Figueroa High School       81.158020
# Ford High School           80.746258
# Griffin High School        83.816757
# Hernandez High School      80.934412
# Holden High School         83.814988
# Huang High School          81.182722
# Johnson High School        80.966394
# Pena High School           84.044699
# Rodriguez High School      80.744686
# Shelton High School        83.725724
# Thomas High School         83.848930
# Wilson High School         83.989488
# Wright High School         83.955000

# %%
# school_data_complete['% Passed math_score'] = (school_data_complete['math_score']>69.99999999)

# passed_math20 = school_data_complete['% Passed math_score'].astype(int)
# passed_math20.sum() / len(passed_math20)

# school_data_complete

school_data_complete['% Passed math_score2']=school_data_complete['math_score'].apply(lambda x: 1 if x >69.99999 else 0)
math500 = school_data_complete.groupby(["school_name"])["% Passed math_score2"].mean() *100
math500
# Out:
# school_name
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# Name: % Passed math_score2, dtype: float64

# %%
school_data_complete['% Passed reading_score2']=school_data_complete['reading_score'].apply(lambda x: 1 if x >69.99999 else 0)
reading500 = school_data_complete.groupby(["school_name"])["% Passed reading_score2"].mean() *100
reading500
# Out:
# school_name
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# Name: % Passed reading_score2, dtype: float64

# %%
school_data_complete['% Passed both_score2']=(school_data_complete['math_score']>69.999999) & (school_data_complete["reading_score"] > 69.99999)
result = school_data_complete['% Passed both_score2'].astype(int)


school_data_complete["% Passed both_score3"] = result
school_data_complete

both500 = school_data_complete.groupby(["school_name"])["% Passed both_score3"].mean() *100
both500
# Out:
# school_name
# Bailey High School       54.642283
# Cabrera High School      91.334769
# Figueroa High School     53.204476
# Ford High School         54.289887
# Griffin High School      90.599455
# Hernandez High School    53.527508
# Holden High School       89.227166
# Huang High School        53.513884
# Johnson High School      53.539172
# Pena High School         90.540541
# Rodriguez High School    52.988247
# Shelton High School      89.892107
# Thomas High School       90.948012
# Wilson High School       90.582567
# Wright High School       90.333333
# Name: % Passed both_score3, dtype: float64

# %%
school_type300["Average Math Score"] = school_type2
school_type300
# Out:
#                            type  Student ID   budget  per Student Budget  \
# school_name
# Bailey High School     District        4976  3124928               628.0
# Cabrera High School     Charter        1858  1081356               582.0
# Figueroa High School   District        2949  1884411               639.0
# Ford High School       District        2739  1763916               644.0
# Griffin High School     Charter        1468   917500               625.0
# Hernandez High School  District        4635  3022020               652.0
# Holden High School      Charter         427   248087               581.0
# Huang High School      District        2917  1910635               655.0
# Johnson High School    District        4761  3094650               650.0
# Pena High School        Charter         962   585858               609.0
# Rodriguez High School  District        3999  2547363               637.0
# Shelton High School     Charter        1761  1056600               600.0
# ...

# %%
school_type300["Average Reading Score"] = school_type3

# %%
school_type300["% Passing Math"] = math500

# %%
school_type300["% Passing Reading"] = reading500

# %%
school_type300["% Overall Passing"] = both500

# %%
school_type300
# Out:
#                            type  Student ID   budget  per Student Budget  \
# school_name
# Bailey High School     District        4976  3124928               628.0
# Cabrera High School     Charter        1858  1081356               582.0
# Figueroa High School   District        2949  1884411               639.0
# Ford High School       District        2739  1763916               644.0
# Griffin High School     Charter        1468   917500               625.0
# Hernandez High School  District        4635  3022020               652.0
# Holden High School      Charter         427   248087               581.0
# Huang High School      District        2917  1910635               655.0
# Johnson High School    District        4761  3094650               650.0
# Pena High School        Charter         962   585858               609.0
# Rodriguez High School  District        3999  2547363               637.0
# Shelton High School     Charter        1761  1056600               600.0
# ...

# %%
school_type300.columns = ['School Type', 'Total Students', 'Total School Budget', 'Per Student Budget', 'Average Math Score', 'Average Reading Score', '% Passing Math', "% Passing Reading","% Overall Passing"]

school_type300
# Out:
#                       School Type  Total Students  Total School Budget  \
# school_name
# Bailey High School       District            4976              3124928
# Cabrera High School       Charter            1858              1081356
# Figueroa High School     District            2949              1884411
# Ford High School         District            2739              1763916
# Griffin High School       Charter            1468               917500
# Hernandez High School    District            4635              3022020
# Holden High School        Charter             427               248087
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Pena High School          Charter             962               585858
# Rodriguez High School    District            3999              2547363
# Shelton High School       Charter            1761              1056600
# ...

# %%
school_type300.style.format({'School Type':"{:20}", 'Total Students':"{:20}", 'Total School Budget':"${:20,.2f}",
       'Per Student Budget':"${:20,.2f}", 'Average Math Score':"{:20,.2f}", 'Average Reading Score':"{:20,.2f}", "% Passing Math":"{:20,.2f}",
       '% Passing Reading':"{:20,.2f}", '% Overall Passing': "{:20,.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_efc43_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >School Type</th>
#       <th class="col_heading level0 col1" >Total Students</th>
#       <th class="col_heading level0 col2" >Total School Budget</th>
#       <th class="col_heading level0 col3" >Per Student Budget</th>
#       <th class="col_heading level0 col4" >Average Math Score</th>
#       <th class="col_heading level0 col5" >Average Reading Score</th>
#       <th class="col_heading level0 col6" >% Passing Math</th>
#       <th class="col_heading level0 col7" >% Passing Reading</th>
#       <th class="col_heading level0 col8" >% Overall Passing</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >school_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
# ...

# %%
school_type300.sort_values(["% Overall Passing"], ascending=False).head(5)
# Out:
#                     School Type  Total Students  Total School Budget  \
# school_name
# Cabrera High School     Charter            1858              1081356
# Thomas High School      Charter            1635              1043130
# Griffin High School     Charter            1468               917500
# Wilson High School      Charter            2283              1319574
# Pena High School        Charter             962               585858
#
#                      Per Student Budget  Average Math Score  \
# school_name
# Cabrera High School               582.0           83.061895
# Thomas High School                638.0           83.418349
# Griffin High School               625.0           83.351499
# Wilson High School                578.0           83.274201
# Pena High School                  609.0           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# school_name
# ...

# %%
school_type300.sort_values(["% Overall Passing"], ascending=True).head(5)
# Out:
#                       School Type  Total Students  Total School Budget  \
# school_name
# Rodriguez High School    District            3999              2547363
# Figueroa High School     District            2949              1884411
# Huang High School        District            2917              1910635
# Hernandez High School    District            4635              3022020
# Johnson High School      District            4761              3094650
#
#                        Per Student Budget  Average Math Score  \
# school_name
# Rodriguez High School               637.0           76.842711
# Figueroa High School                639.0           76.711767
# Huang High School                   655.0           76.629414
# Hernandez High School               652.0           77.289752
# Johnson High School                 650.0           77.072464
#
#                        Average Reading Score  % Passing Math  \
# school_name
# ...

# %%
#https://www.kite.com/python/answers/how-to-reorder-columns-in-a-pandas-dataframe-in-python

math_grade = school_data_complete.groupby(["school_name","grade"]).math_score.mean().unstack()
column_names = ["9th", "10th", "11th", "12th"]

math_grade = math_grade.reindex(columns=column_names)
math_grade
# Out:
# grade                        9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %%
reading_grade = school_data_complete.groupby(["school_name","grade"]).reading_score.mean().unstack()
column_names = ["9th", "10th", "11th", "12th"]

reading_grade = reading_grade.reindex(columns=column_names)
reading_grade
# Out:
# grade                        9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %%
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# ...

# %%
Bins=[0, 584,629,644,9999999]

school_type300['bins'] = pd.cut(x=school_type300['Per Student Budget'], bins=Bins)
school_type300
# Out:
#                       School Type  Total Students  Total School Budget  \
# school_name
# Bailey High School       District            4976              3124928
# Cabrera High School       Charter            1858              1081356
# Figueroa High School     District            2949              1884411
# Ford High School         District            2739              1763916
# Griffin High School       Charter            1468               917500
# Hernandez High School    District            4635              3022020
# Holden High School        Charter             427               248087
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Pena High School          Charter             962               585858
# Rodriguez High School    District            3999              2547363
# Shelton High School       Charter            1761              1056600
# ...

# %%
school_type300.groupby("bins").agg({"Average Math Score": "mean", "Average Reading Score":"mean","% Passing Math":"mean","% Passing Reading":"mean","% Overall Passing":"mean"})
# Out:
#                 Average Math Score  Average Reading Score  % Passing Math  \
# bins
# (0, 584]                 83.455399              83.933814       93.460096
# (584, 629]               81.899826              83.155286       87.133538
# (629, 644]               78.518855              81.624473       73.484209
# (644, 9999999]           76.997210              81.027843       66.164813
#
#                 % Passing Reading  % Overall Passing
# bins
# (0, 584]                96.610877          90.369459
# (584, 629]              92.718205          81.418596
# (629, 644]              84.391793          62.857656
# (644, 9999999]          81.133951          53.526855

# %%
school_type300
# Out:
#                       School Type  Total Students  Total School Budget  \
# school_name
# Bailey High School       District            4976              3124928
# Cabrera High School       Charter            1858              1081356
# Figueroa High School     District            2949              1884411
# Ford High School         District            2739              1763916
# Griffin High School       Charter            1468               917500
# Hernandez High School    District            4635              3022020
# Holden High School        Charter             427               248087
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Pena High School          Charter             962               585858
# Rodriguez High School    District            3999              2547363
# Shelton High School       Charter            1761              1056600
# ...

# %%
school_type300.groupby("bins2").agg({"Average Math Score": "mean", "Average Reading Score":"mean","% Passing Math":"mean","% Passing Reading":"mean","% Overall Passing":"mean"})
# Out:
#                  Average Math Score  Average Reading Score  % Passing Math  \
# bins2
# (0, 999]                  83.821598              83.929843       93.550225
# (999, 2000]               83.374684              83.864438       93.599695
# (2000, 9999999]           77.746417              81.344493       69.963361
#
#                  % Passing Reading  % Overall Passing
# bins2
# (0, 999]                 96.099437          89.883853
# (999, 2000]              96.790680          90.621535
# (2000, 9999999]          82.766634          58.286003

# %%
school_type300.groupby("School Type").agg({"Average Math Score": "mean", "Average Reading Score":"mean","% Passing Math":"mean","% Passing Reading":"mean","% Overall Passing":"mean"})
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.586489          90.432244
# District             80.799062          53.672208
